# %%
formuladl1216_account_key = dbutils.secrets.get(scope = 'formula1-scope', key = 'formuladl1216-account-key')

# %%
spark.conf.set(
    "fs.azure.account.key.formula1dl1216.dfs.core.windows.net",formuladl1216_account_key)

# %%
display(dbutils.fs.ls("abfss://demo@formuladl.dfs.core.windows.net"))

# %%
display(spark.read.csv("abfss://demo@formuladl.dfs.core.windows.net/circuits.csv"))
