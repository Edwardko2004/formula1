# %% [markdown]
# ### Explore DBFS Root
# 1. List all of the folders in DBFS root
# 2. Interact with DBFS File Browser
# 3. Upload File to DBFS

# %%
display(dbutils.fs.ls('/'))

# %%
display(dbutils.fs.ls('/FileStore'))

# %%
display(spark.read.csv('/FileStore/circuits.csv'))
